# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt 
import seaborn as sns 
import plotly as py
import plotly.graph_objs as go
from sklearn.cluster import KMeans

# %%
df=pd.read_csv("Mall_Customers.csv")
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.shape
# Out:
# (200, 5)

# %%
from sklearn import preprocessing as pr
le=pr.LabelEncoder()
df["Genre"]=le.fit_transform(df["Genre"])

# %%
df.head()
# Out:
#    CustomerID  Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1      1   19                  15                      39
# 1           2      1   21                  15                      81
# 2           3      0   20                  16                       6
# 3           4      0   23                  16                      77
# 4           5      0   31                  17                      40

# %%
df.set_index('CustomerID', inplace=True)
df.head()
# Out:
#             Genre  Age  Annual Income (k$)  Spending Score (1-100)
# CustomerID
# 1               1   19                  15                      39
# 2               1   21                  15                      81
# 3               0   20                  16                       6
# 4               0   23                  16                      77
# 5               0   31                  17                      40

# %%
df.isnull().sum()
# Out:
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
plt.style.use('fivethirtyeight')
plt.figure(1,figsize=(15,6))
n=0
for x in ['Age','Annual Income (k$)','Spending Score (1-100)']:
    n+=1
    plt.subplot(1,3,n)
    plt.subplots_adjust(hspace =0.5 , wspace = 0.5)
    sns.histplot(df[x] , bins = 20)
    plt.title('Distplot of {}'.format(x))
plt.show()

# %%
plt.figure(1 , figsize = (15 , 7))
n = 0 
for x in ['Age' , 'Annual Income (k$)' , 'Spending Score (1-100)']:
    for y in ['Age' , 'Annual Income (k$)' , 'Spending Score (1-100)']:
        n += 1
        plt.subplot(3 , 3 , n)
        plt.subplots_adjust(hspace = 0.5 , wspace = 0.5)
        sns.scatterplot(x = x , y = y , data = df)
        plt.ylabel(y.split()[0]+' '+y.split()[1] if len(y.split()) > 1 else y )
plt.show()

# %%
X=df[['Age','Annual Income (k$)']]
y=df['Spending Score (1-100)']
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size = 0.30, random_state = 0)

# %%
inertia=[]
for n in range(1,11):
    algo=(KMeans(n_clusters=n,max_iter=300,tol=0.0001,init='k-means++',n_init=10,algorithm='elkan'))
    algo.fit(X_train,y_train)
    inertia.append(algo.inertia_)
# Out:
# C:\Users\pranj\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1373: RuntimeWarning: algorithm='elkan' doesn't make sense for a single cluster. Using 'lloyd' instead.
#   warnings.warn(
# C:\Users\pranj\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
plt.figure(1 , figsize = (15 ,6))
plt.plot(np.arange(1 , 11) , inertia , 'o')
plt.plot(np.arange(1 , 11) , inertia , '-' , alpha = 0.5)
plt.xlabel('Number of Clusters') , plt.ylabel('Inertia')
plt.show()

# %%
algorithm = (KMeans(n_clusters = 4 ,init='k-means++', n_init = 10 ,max_iter=300, 
                        tol=0.0001,  random_state= 111  , algorithm='elkan') )
algorithm.fit(X_train,y_train)
labels1 = algorithm.labels_
centroids1 = algorithm.cluster_centers_

# %%
y_pred=algorithm.predict(X_test)

# %%
y_pred
# Out:
# array([3, 1, 3, 3, 1, 2, 0, 3, 3, 1, 0, 1, 2, 3, 3, 0, 0, 3, 0, 3, 2, 1,
#        0, 1, 3, 1, 2, 2, 1, 3, 0, 3, 1, 1, 0, 2, 1, 0, 3, 3, 1, 3, 0, 1,
#        1, 3, 3, 1, 3, 1, 3, 1, 2, 1, 1, 3, 3, 3, 3, 3])

# %%
y_test
# Out:
# CustomerID
# 19     29
# 171    13
# 108    46
# 99     42
# 178    69
# 183    15
# 6      76
# 147    36
# 13     15
# 153    20
# 62     55
# 126    77
# 181    32
# 155    16
# 81     51
# 8      94
# 34     92
# 131     9
# 38     73
# 75     47
# 184    88
# 146    97
# 46     65
# 160    73
# 61     56
# 124    91
# 180    90
# 186    97
# 123    58
# 45     28
# 17     35
# 56     41
# 151    17
# 112    54
# 23      5
# 190    85
# 130    75
# 5      40
# 84     44
# 107    50
# 135     5
# 67     50
# 27     32
# 114    46
# 169    27
# 64     59
# 9       3
# 76     54
# 119    43
# 144    87
# 72     42
# 125    29
# 185    39
# 98     50
# 150    90
# 25     14
# 31      4
# 161    35
# 41     35
# 57     50
# Name: Spending Score (1-100), dtype: int64

# %%
from sklearn.metrics import adjusted_rand_score

ari = adjusted_rand_score(y_test, y_pred)
ari
# Out:
# 0.0018934095034842638

# %%
from sklearn.metrics import homogeneity_completeness_v_measure

homogeneity, completeness, v_measure = homogeneity_completeness_v_measure(y_test, y_pred)

# %%
homogeneity
# Out:
# 0.27604721854246306

# %%
completeness
# Out:
# 0.8014314043952397

# %%
v_measure
# Out:
# 0.41064927939396706

# %%
from sklearn.metrics import normalized_mutual_info_score

nmi = normalized_mutual_info_score(y_test, y_pred)
nmi
# Out:
# 0.4106492793939671
